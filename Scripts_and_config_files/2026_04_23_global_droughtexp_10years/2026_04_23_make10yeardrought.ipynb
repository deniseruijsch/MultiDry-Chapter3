# %%
import xarray as xr

# %%
pr = xr.open_dataset("/projects/prjs2023/chapter3/lpjml_input/gswp3-w5e5_obsclim_pr_global_daily_1901_2019_version_2021-09-XX_mm_day.nc").sel(time = slice("1960","2010"))
pr
# Out:
# <xarray.Dataset> Size: 19GB
# Dimensions:  (time: 18628, lat: 360, lon: 720)
# Coordinates:
#   * time     (time) datetime64[ns] 149kB 1960-01-01 1960-01-02 ... 2010-12-31
#   * lat      (lat) float32 1kB 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * lon      (lon) float32 3kB -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
# Data variables:
#     pr       (time, lat, lon) float32 19GB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.3 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  Potsdam Institute for Climate Impact Research (PIK)
#     title:        GSWP3-W5E5 observational climate input data for ISIMIP3a
#     project:      Inter-Sectoral Impact Model Intercomparison Project phase 3...
#     contact:      ISIMIP cross-sectoral science team <info@isimip.org> <https...
#     summary:      GSWP3 v1.09 bias-adjusted to W5E5 v2.0 with ISIMIP3BASD v2....
# ...

# %%
pr.pr[0].plot()

# %%
pr_zeroed = pr.copy()
pr_zeroed['pr'].loc[dict(time=slice("1970", "1979"))] = 0
pr_zeroed

# %%
pr_zeroed.sel(lon = 10, lat = 53, method = "nearest").pr.plot()

# %%
pr_zeroed.to_netcdf("/projects/prjs2023/chapter3/lpjml_input/droughtexp_10years/pr_1960_2010_zeroed_1970_1979_global.nc")

# %%
pre_zero = xr.open_dataset("/projects/prjs2023/chapter3/lpjml_input/droughtexp_10years/pr_1960_2010_zeroed_1970_1979_global_slurm.nc")
pre_zero
# Out:
# <xarray.Dataset> Size: 19GB
# Dimensions:  (time: 18628, lat: 360, lon: 720)
# Coordinates:
#   * time     (time) datetime64[ns] 149kB 1960-01-01 1960-01-02 ... 2010-12-31
#   * lat      (lat) float32 1kB 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * lon      (lon) float32 3kB -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
# Data variables:
#     pr       (time, lat, lon) float32 19GB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.3 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  Potsdam Institute for Climate Impact Research (PIK)
#     title:        GSWP3-W5E5 observational climate input data for ISIMIP3a
#     project:      Inter-Sectoral Impact Model Intercomparison Project phase 3...
#     contact:      ISIMIP cross-sectoral science team <info@isimip.org> <https...
#     summary:      GSWP3 v1.09 bias-adjusted to W5E5 v2.0 with ISIMIP3BASD v2....
# ...

# %%
pre_zero.sel(lon = 10, lat = 53, method = "nearest").pr.plot()
